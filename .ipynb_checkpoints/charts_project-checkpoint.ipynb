# %% [markdown]
# # 1. Preparation for working with data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import plotly
import dotenv
import os

# %% [markdown]
# #2. API queries.

# %%
dotenv.load_dotenv()
API_URL = os.getenv('API_URL')
DATE_BEGIN = os.getenv('DATE_BEGIN')
DATE_END = os.getenv('DATE_END')

# %%
visits = requests.get(f'{API_URL}/visits?begin={DATE_BEGIN}&end={DATE_END}')
#visits = requests.get('https://data-charts-api.hexlet.app/visits?begin=2023-03-01&end=2023-09-01')
visits.status_code
# Out:
# 200

# %%
regs = requests.get(f'{API_URL}/registrations?begin={DATE_BEGIN}&end={DATE_END}')
#regs = requests.get('https://data-charts-api.hexlet.app/registrations?begin=2023-03-01&end=2023-09-01')
regs.status_code
# Out:
# 200

# %% [markdown]
# #3. Metrics counting.

# %%
visits_df = pd.DataFrame(visits.json())
visits_df.head()
# Out:
#                                visit_id platform  \
# 0  59c69c6f-81b3-4e63-b1b3-00a950cf9feb      web
# 1  a82c5ae1-3d3b-485e-a483-df963c5e0e7a      web
# 2  a82c5ae1-3d3b-485e-a483-df963c5e0e7a      web
# 3  87525d18-3dce-4d81-8fa8-47d900c70a90      web
# 4  87525d18-3dce-4d81-8fa8-47d900c70a90      web
#
#                                           user_agent             datetime
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...  2023-07-17T22:11:52
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...  2023-07-21T16:44:14
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...  2023-07-18T04:13:34
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  2023-07-21T23:35:16
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  2023-07-20T20:23:04

# %%
regs_df = pd.DataFrame(regs.json())
regs_df.head()
# Out:
#               datetime                               user_id  \
# 0  2023-03-01T07:40:13  2e0f6bb8-b029-4f45-a786-2b53990d37f1
# 1  2023-03-01T13:14:00  f007f97c-9d8b-48b5-af08-119bb8f6d9b6
# 2  2023-03-01T03:05:50  24ff46ae-32b3-4a74-8f27-7cf0b8f32f15
# 3  2023-03-01T00:04:47  3e9914e1-5d73-4c23-b25d-b59a3aeb2b60
# 4  2023-03-01T18:31:52  27f875fc-f8ce-4aeb-8722-0ecb283d0760
#
#                         email platform registration_type
# 0           ebyrd@example.org      web            google
# 1    knightgerald@example.org      web             email
# 2  cherylthompson@example.com      web             apple
# 3       halldavid@example.org      web             email
# 4        denise86@example.net      web            google

# %%
def prepare_visits(vis_df):
  vis_df = vis_df.copy()

  # cleaning from bots
  mask = vis_df['user_agent'].str.contains('bot')
  vis_df = vis_df[~mask]

  # cleaning user_id duplicates
  vis_df['datetime'] = pd.to_datetime(vis_df['datetime'])
  vis_df = vis_df.sort_values(by=['visit_id', 'datetime']).drop_duplicates(subset='visit_id', keep='last')

  # grouping and counting total amount of visits per date and platform
  vis_df['date_group'] = vis_df['datetime'].dt.date
  vis_df = vis_df.sort_values(by='date_group')
  vis_df = vis_df.groupby(['date_group', 'platform']).size().reset_index(name='visits')
  return vis_df


visits_df = prepare_visits(visits_df)
visits_df.head()
# Out:
#    date_group platform  visits
# 0  2023-03-01  android      75
# 1  2023-03-01      ios      22
# 2  2023-03-01      web     279
# 3  2023-03-02  android      67
# 4  2023-03-02      ios      31

# %%
def prepare_regs(df):
  df = df.copy()
  df['datetime'] = pd.to_datetime(df['datetime'])
  df = df.sort_values(by='datetime')
  df['date_group'] = df['datetime'].dt.date

  # grouping and counting total amount of registrations per date and platform
  df = df.groupby(['date_group', 'platform']).size().reset_index(name='registrations')
  return df


regs_df = prepare_regs(regs_df)
regs_df.head()
# Out:
#    date_group platform  registrations
# 0  2023-03-01  android             61
# 1  2023-03-01      ios             18
# 2  2023-03-01      web              8
# 3  2023-03-02  android             59
# 4  2023-03-02      ios             24

# %%
def visits_and_regs_conversion(df_vis, df_regs):
  df = pd.merge(df_vis, df_regs, on=['date_group', 'platform'], how='inner')
  df['conversion'] = (df['registrations'] / df['visits']) * 100

  #df = df.reset_index()
  df = df.sort_values(by=['date_group', 'platform'])
  with open('./conversion.json', 'w', encoding='utf-8') as f:
    df.to_json(f, force_ascii=False) #, sort_keys=False, orient='columns')

  return df


vis_regs_conv = visits_and_regs_conversion(visits_df, regs_df)
vis_regs_conv.head(10)
# Out:
#    date_group platform  visits  registrations  conversion
# 0  2023-03-01  android      75             61   81.333333
# 1  2023-03-01      ios      22             18   81.818182
# 2  2023-03-01      web     279              8    2.867384
# 3  2023-03-02  android      67             59   88.059701
# 4  2023-03-02      ios      31             24   77.419355
# 5  2023-03-02      web     515             23    4.466019
# 6  2023-03-03  android      26             22   84.615385
# 7  2023-03-03      ios      40             34   85.000000
# 8  2023-03-03      web     617             51    8.265802
# 9  2023-03-04  android      94             77   81.914894

# %% [markdown]
# # 4. Adds adding.

# %%
ads_df = pd.read_csv('./ads.csv')
ads_df.head()
# Out:
#                   date utm_source utm_medium                utm_campaign  cost
# 0  2023-03-01T10:54:41     google        cpc  advanced_algorithms_series   212
# 1  2023-03-02T10:32:35     google        cpc  advanced_algorithms_series   252
# 2  2023-03-03T19:21:40     google        cpc  advanced_algorithms_series   202
# 3  2023-03-04T17:52:04     google        cpc  advanced_algorithms_series   223
# 4  2023-03-05T05:35:13     google        cpc  advanced_algorithms_series   265

# %%
def prepare_ads(ads_df):
  df = ads_df.copy()

  # preparing date_group column
  df['date'] = pd.to_datetime(df['date'])
  df = df.sort_values(by='date')
  df['date_group'] = df['date'].dt.date

  # just in case
  df['cost'] = df['cost'].fillna(0)
  df['utm_campaign'] = df['utm_campaign'].fillna('none')
  df = df.drop_duplicates()

  # selecting the required time period
  #mask = (
  #    (df['date_group'] >= pd.to_datetime('2023-03-01').date()) &
  #    (df['date_group'] <= pd.to_datetime('2023-09-01').date())
  #)
  mask = (
      (df['date_group'] >= pd.to_datetime(f'{DATE_BEGIN}').date()) &
      (df['date_group'] <= pd.to_datetime(f'{DATE_END}').date())
  )
  df = df[mask]

  df = df.groupby(['date_group', 'utm_campaign'])['cost'].sum().reset_index()
  return df


ads_df = prepare_ads(ads_df)
ads_df.head(100)
# Out:
#     date_group                utm_campaign  cost
# 0   2023-03-01  advanced_algorithms_series   212
# 1   2023-03-02  advanced_algorithms_series   252
# 2   2023-03-03  advanced_algorithms_series   202
# 3   2023-03-04  advanced_algorithms_series   223
# 4   2023-03-05  advanced_algorithms_series   265
# ..         ...                         ...   ...
# 95  2023-07-06     women_in_tech_symposium   252
# 96  2023-07-07     women_in_tech_symposium   243
# 97  2023-07-08     women_in_tech_symposium   171
# 98  2023-07-09     women_in_tech_symposium   197
# 99  2023-07-10     women_in_tech_symposium   235
#
# [100 rows x 3 columns]

# %%
def add_ads_to_res(ads_df, vis_regs_conv):
  df = pd.merge(vis_regs_conv, ads_df, on='date_group', how='left')

  # replacing the incorrect data
  df['utm_campaign'] = df['utm_campaign'].fillna('none')
  df['cost'] = df['cost'].fillna(0)

  #df = df.reset_index()
  df = df.sort_values(by=['date_group', 'platform'])
  with open('./ads.json', 'w', encoding='utf-8') as f:
    df.to_json(f, force_ascii=False) #, sort_keys=False, orient='columns')

  return df


vis_regs_conv_and_ads = add_ads_to_res(ads_df, vis_regs_conv)
vis_regs_conv_and_ads.head(600)
# Out:
#      date_group platform  visits  registrations  conversion  \
# 0    2023-03-01  android      75             61   81.333333
# 1    2023-03-01      ios      22             18   81.818182
# 2    2023-03-01      web     279              8    2.867384
# 3    2023-03-02  android      67             59   88.059701
# 4    2023-03-02      ios      31             24   77.419355
# ..          ...      ...     ...            ...         ...
# 547  2023-08-30      ios      66             40   60.606061
# 548  2023-08-30      web    1227             34    2.770986
# 549  2023-08-31  android      57             42   73.684211
# 550  2023-08-31      ios      50             36   72.000000
# 551  2023-08-31      web     721             46    6.380028
#
#                    utm_campaign   cost
# 0    advanced_algorithms_series  212.0
# 1    advanced_algorithms_series  212.0
# 2    advanced_algorithms_series  212.0
# 3    advanced_algorithms_series  252.0
# 4    advanced_algorithms_series  252.0
# ...

# %% [markdown]
# # 5. Visualization.

# %%
def prepare_data(df):
  weekly_data = df.copy()

  # dividing data into weekly periods where week may start at every date
  weekly_data['week'] = pd.to_datetime(weekly_data['date_group'])
  weekly_data['week'] = weekly_data['week'].dt.to_period('W').dt.start_time.dt.date

  # summarising vis, regs statistics and recounting the conversion
  weekly_data_conv = weekly_data.groupby('week').sum(['visits', 'registrations']).reset_index()
  weekly_data_conv['conversion'] = (weekly_data_conv['registrations'] / weekly_data_conv['visits']) * 100

  # summarising the statistics by each platform
  weekly_data_conv_by_platform = weekly_data.groupby(['week', 'platform']).sum(['visits', 'registrations']).reset_index()
  weekly_data_conv_by_platform['conversion'] = (weekly_data_conv_by_platform['registrations'] / weekly_data_conv_by_platform['visits']) * 100

  return weekly_data_conv, weekly_data_conv_by_platform


weekly_data, weekly_data_by_platform = prepare_data(vis_regs_conv_and_ads)
weekly_data_by_platform.head()
# Out:
#          week platform  visits  registrations  conversion    cost
# 0  2023-02-27  android     328            273   83.231707  1154.0
# 1  2023-02-27      ios     177            132   74.576271  1154.0
# 2  2023-02-27      web    2521            169    6.703689  1154.0
# 3  2023-03-06  android     733            522   71.214188  1172.0
# 4  2023-03-06      ios     296            214   72.297297  1172.0

# %%
def is_dir(path):
  if not os.path.isdir('./charts'):
    os.mkdir('./charts')

# %%
def total_visits(df):
  fig, ax = plt.subplots(figsize=(14,7))
  ax.bar(x='week', height='visits', data=df, width=5)

  plt.title('Total visits', fontsize=16)

  plt.xlabel('Date (weekly)', fontsize=14)
  plt.xticks(df['week'], rotation=45)
  plt.ylabel('Visits', fontsize=14)

  plt.grid(axis='y')
  plt.tight_layout()
  plt.show()

  is_dir('./charts')
  plt.savefig('./charts/total_visits.png')


total_visits(weekly_data)

# %%
def total_visits_by_platform(df):
  fig, ax = plt.subplots(figsize=(14,7))

  # forming the brand new table by transposing the inital matrix
  # with the required entries only in order to simplify the graph plotting
  df = df.pivot_table(index='week', columns='platform', values='visits')
  df.plot(kind='bar', stacked=True, ax=ax)

  plt.title('Total visits by platform', fontsize=16)
  plt.xlabel('Date (weekly)', fontsize=14)
  plt.xticks(rotation=45)
  plt.ylabel('Visits', fontsize=14)

  plt.grid(axis='y')
  plt.tight_layout()
  plt.show()

  is_dir('./charts')
  plt.savefig('./charts/total_visits_by_platform.png')


total_visits_by_platform(weekly_data_by_platform)

# %%
def total_regs(df):
  fig, ax = plt.subplots(figsize=(14,7))
  ax.bar(x='week', height='registrations', data=df, width=5)

  plt.title('Total registrations', fontsize=16)
  plt.xlabel('Date (weekly)', fontsize=14)
  plt.xticks(df['week'], rotation=45)
  plt.ylabel('Registrations', fontsize=14)

  plt.grid(axis='y')
  plt.tight_layout()
  plt.show()

  is_dir('./charts')
  plt.savefig('./charts/total_registrations.png')


total_regs(weekly_data)

# %%
def total_regs_by_platform(df):
  fig, ax = plt.subplots(figsize=(14,7))

  # reformatting amd making the table simplier by saving only demanded data
  df = df.pivot_table(index='week', columns='platform', values='registrations')
  df.plot(kind='bar', stacked=True, ax=ax)

  plt.title('Total registrations by platform', fontsize=16)
  plt.xlabel('Date (weekly)', fontsize=14)
  plt.xticks(rotation=45)
  plt.ylabel('Registrations', fontsize=14)

  plt.grid(axis='y')
  plt.tight_layout()
  plt.show()

  is_dir('./charts')
  plt.savefig('./charts/total_regs_by_platform.png')


total_regs_by_platform(weekly_data_by_platform)

# %%
def conversion_by_platform(df):
  fig, ax = plt.subplots(3, 1, figsize=(14,14))
  fig.suptitle('Conversion by each platform', fontsize=16)

  df = df.pivot_table(index='week', columns='platform', values='conversion')

  ax[0].plot(df.index, df['android'], label='Android')
  ax[0].set_title('Android', fontsize=16)
  ax[0].tick_params(rotation=45, axis='x')
  ax[0].xaxis.set_major_locator(plt.MaxNLocator(nbins=30))
  ax[0].set_ylabel('Conversion (%)', fontsize=14)
  ax[0].set_xlabel('Date (weekly)', fontsize=14)
  ax[0].legend()
  ax[0].grid()

  ax[1].plot(df.index, df['ios'], label='Ios')
  ax[1].set_title('Ios', fontsize=16)
  ax[1].tick_params(rotation=45, axis='x')
  ax[1].xaxis.set_major_locator(plt.MaxNLocator(nbins=30))
  ax[1].set_ylabel('Conversion (%)', fontsize=14)
  ax[1].set_xlabel('Date (weekly)', fontsize=14)
  ax[1].legend()
  ax[1].grid()

  ax[2].plot(df.index, df['web'], label='Web')
  ax[2].set_title('Web', fontsize=16)
  ax[2].tick_params(rotation=45, axis='x')
  ax[2].xaxis.set_major_locator(plt.MaxNLocator(nbins=30))
  ax[2].set_ylabel('Conversion (%)', fontsize=14)
  ax[2].set_xlabel('Date (weekly)', fontsize=14)
  ax[2].legend()
  ax[2].grid()

  plt.tight_layout()
  plt.show()

  is_dir('./charts')
  plt.savefig('./charts/conversion_by_platform.png')


conversion_by_platform(weekly_data_by_platform)

# %%
def average_conv(df):
  fig, ax = plt.subplots(figsize=(14,7))

  # need to display the average conversion (mean) value of 3 platforms per week
  df = df.groupby('week')['conversion'].mean()
  df.plot(ax=ax)

  plt.title('Average conversion', fontsize=16)
  plt.xlabel('Date (weekly)', fontsize=14)
  plt.xticks(df.index, rotation=45)
  plt.ylabel('Conversion (%)', fontsize=14)

  plt.grid()
  plt.tight_layout()
  plt.show()

  is_dir('./charts')
  plt.savefig('./charts/average_conversion.png')


average_conv(weekly_data_by_platform)

# %%
def ads_cost(df):
  fig, ax = plt.subplots(figsize=(14,7))
  plt.plot(df['week'], df['cost'])

  plt.title('Advertising costs', fontsize=16)
  plt.xlabel('Date (weekly)', fontsize=14)
  plt.xticks(df['week'], rotation=45)
  plt.ylabel('Cost', fontsize=14)

  plt.grid()
  plt.tight_layout()
  plt.show()

  is_dir('./charts')
  plt.savefig('./charts/advertising_costs.png')


ads_cost(weekly_data)

# %%
def prepare_ads_periods(df):
  df = df.copy()

  df = df[['date_group', 'utm_campaign']]
  ads_names = df['utm_campaign'].unique()
  ads_names = np.delete(ads_names, np.where(ads_names == 'none'))

  for name in ads_names:
    tmp = df.loc[df['utm_campaign'] == name]
    yield tmp['date_group'].min(), tmp['date_group'].max(), name


def ads_influencing(df):
  fig, ax = plt.subplots(2, 1, figsize=(14,14))
  fig.suptitle('Ads campaigns results', fontsize=16)

  ax[0].plot(df['week'], df['visits'], label='Visits')
  ax[0].axhline(y=df['visits'].mean(), color='grey', linestyle='dashed', label='Mean')

  # initializing of the generator
  gen = prepare_ads_periods(vis_regs_conv_and_ads)
  for min, max, name in gen:
    ax[0].axvspan(xmin=min, xmax=max, label=name, color=np.random.rand(4,))

  ax[0].set_title('Unique visits amount', fontsize=16)
  ax[0].tick_params(rotation=45, axis='x')
  ax[0].xaxis.set_major_locator(plt.MaxNLocator(nbins=30))
  ax[0].set_ylabel('Quantity', fontsize=14)
  ax[0].set_xlabel('Date (weekly)', fontsize=14)
  ax[0].legend()
  ax[0].grid()


  ax[1].plot(df['week'], df['registrations'], label='Registrations')
  ax[1].axhline(y=df['registrations'].mean(), color='grey', linestyle='dashed', label='Mean')

  # re-initializing of the generator
  gen = prepare_ads_periods(vis_regs_conv_and_ads)
  for min, max, name in gen:
    ax[1].axvspan(xmin=min, xmax=max, label=name, color=np.random.rand(4,))

  ax[1].set_title('Registrations amount', fontsize=16)
  ax[1].tick_params(rotation=45, axis='x')
  ax[1].xaxis.set_major_locator(plt.MaxNLocator(nbins=30))
  ax[1].set_ylabel('Quantity', fontsize=14)
  ax[1].set_xlabel('Date (weekly)', fontsize=14)
  ax[1].legend()
  ax[1].grid()

  plt.tight_layout()
  plt.show()

  is_dir('./charts')
  plt.savefig('./charts/ads_influencing.png')


ads_influencing(weekly_data)
